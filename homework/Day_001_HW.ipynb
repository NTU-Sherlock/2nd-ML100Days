# %% [markdown]
# ### Day1 題目
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估
#
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ### 作業1：
# 我選擇MovieLens 20M Dataset電影評分資料進行分析
# https://grouplens.org/datasets/movielens/20m/
#
# 1. 我認為這份資料值得分析的原因有兩個：一則是能幫助電影商了解何種類型的電影符合觀眾的口味，對於未來製作新電影時能有所借鏡；二則是能夠幫助戲院規劃檔期，預測該部電影應該放映多久，有效利用戲院資源。
# 2. 這份資料來來自於MovieLens，一個致力於幫助個人化電影推薦的網站，透過該用戶對每部電影的評分推薦其他用戶可能會喜歡的電影。該網站為University of Minnesota的實驗室，因此資料為公開且免費。
# 3. 該資料為結構化資料，需要檢視欄欄位意義以及名稱，包括genres, tags,ratings, 以及該電影預告在youtube的點閱.
# 4. 該資料提供0.5~5分的用戶評等資料（每0.5為一單位），如問題為預測該用戶對於一個電影的應屬於迴歸問題，可用MAE, RMSE來評估模型結果。

# %% [markdown]
# ### 作業2：

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 假設人們需要搭車的頻率固定，就以每個月兩次為例，搭車當下能否選擇我們的平台，而不是叫路過小黃、uber便是我們提昇業績的關鍵。在產品同質性高的情況下，價格便是取勝的關鍵，若我們的價格能保證低於uber，消費者選擇我們平台的機會便很高，因此我們需要每趟uber的路線與費用的資料。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 每天定期在不同點使用uber APP點選不同的destination與價格，便能粗估uber的定價方程式
# 3. 蒐集而來的資料型態為何
# 地理資料，可能會像是gis涵蓋了路徑，也有可能只是單純的距離（結構化資料），而Y應為數值資料（價格）
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 預測uber每趟路線的價格為迴歸問題，可用MAE, RMSE來評估模型結果。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    mse = sum((y-y_hat)**2)/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.358

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 195.038
# The Mean absolute error is 11.358
